# %%
tables_df = spark.sql("SHOW TABLES IN samples.accuweather")
display(tables_df)

for row in tables_df.collect():
    table_name = row['tableName']
    df = spark.sql(f"SELECT * FROM samples.accuweather.{table_name}")
    display(df)
